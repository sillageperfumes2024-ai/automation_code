# %%
import pandas as pd
import os
import csv
import json

# %%
import random
import string

def generate_random_alphanumeric(length):
    """
    Generates a random alphanumeric string of a specified length.
    """
    # Define the characters to choose from (digits and uppercase letters)
    characters = string.ascii_uppercase + string.digits
    
    # Use random.choices to select characters and ''.join to create the string
    alphanumeric_string = ''.join(random.choices(characters, k=length))
    
    return alphanumeric_string

# %%
output_columns = ['*Sale Order Number', '*Pickup Location Name', '*Transport Mode',
       '*Payment Mode', 'COD Amount', '*Customer Name', '*Customer Phone',
       '*Shipping Address Line1', 'Shipping Address Line2', '*Shipping City',
       '*Shipping State', '*Shipping Pincode', '*Item Sku Code',
       '*Item Sku Name', '*Quantity Ordered', 'Packaging Type',
       '*Unit Item Price', 'Length (cm)', 'Breadth (cm)', 'Height (cm)',
       'Weight (gm)', 'Fragile Shipment', 'Discount Type', 'Discount Value',
       'Tax Class Code', 'Customer Email',
       'Billing Address same as Shipping Address', 'Billing Address Line1',
       'Billing Address Line2', 'Billing City', 'Billing State',
       'Billing Pincode', 'e-Way Bill Number', 'Seller Name',
       'Seller GST Number', 'Seller Address Line1', 'Seller Address Line2',
       'Seller City', 'Seller State', 'Seller Pincode']

# %%
input_path = r"C:\Users\silla\Downloads\orders_export_23_10_v4.csv"
output_path = r"C:\Users\silla\Downloads\Bulk_Order_Upload_23_10_v4.csv"

# %%
input_df = pd.read_csv(input_path)
grouped_orders = input_df.groupby('Name')

# %%
group_order_dict = {}
for order_number, order_data in grouped_orders:
    group_order_dict[order_number] = {
        "Financial Status": order_data['Financial Status'].iloc[0] if not pd.isna(order_data['Financial Status'].iloc[0]) else "N/A",
        "Subtotal": order_data['Subtotal'].iloc[0] if not pd.isna(order_data['Subtotal'].iloc[0]) else "N/A",
        "Total": order_data['Total'].iloc[0] if not pd.isna(order_data['Total'].iloc[0]) else "N/A",
        "Shipping": order_data['Shipping'].iloc[0] if not pd.isna(order_data['Shipping'].iloc[0]) else "N/A",
        "Discount Amount": order_data['Discount Amount'].iloc[0] if not pd.isna(order_data['Discount Amount'].iloc[0]) else "N/A",
        "Shipping Name": order_data['Shipping Name'].iloc[0] if not pd.isna(order_data['Shipping Name'].iloc[0]) else "N/A",
        "Shipping Phone": str(order_data['Shipping Phone'].iloc[0] if not pd.isna(order_data['Shipping Phone'].iloc[0]) else "N/A").replace(".0","")[-10:],
        "Shipping Street": order_data['Shipping Street'].iloc[0] if not pd.isna(order_data['Shipping Street'].iloc[0]) else "N/A",
        "Shipping City": order_data['Shipping City'].iloc[0] if not pd.isna(order_data['Shipping City'].iloc[0]) else "N/A",
        "Shipping Province": order_data['Shipping Province'].iloc[0] if not pd.isna(order_data['Shipping Province'].iloc[0]) else "N/A",
        "Shipping Zip": order_data['Shipping Zip'].iloc[0] if not pd.isna(order_data['Shipping Zip'].iloc[0]) else "N/A"
    }

# %%
group_order_dict
# Out:
# {'#3189': {'Financial Status': 'pending',
#   'Subtotal': np.float64(1861.0),
#   'Total': np.float64(1960.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Soumya Roy',
#   'Shipping Phone': '8196037748',
#   'Shipping Street': 'Choutara-Bhandarhati Road, Singha roy kali mandir',
#   'Shipping City': 'Durga Prasad',
#   'Shipping Province': 'WB',
#   'Shipping Zip': "'712301"},
#  '#3191': {'Financial Status': 'pending',
#   'Subtotal': np.float64(1390.8),
#   'Total': np.float64(1489.8),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(73.2),
#   'Shipping Name': 'RONAK MEHTA',
#   'Shipping Phone': '8141618747',
#   'Shipping Street': 'C101 SHREE GOKULESH RESIDENCY,SSV School 2 Dabhoi - Waghodia Ring Road, Bs vallabh vidhya mandir',
#   'Shipping City': 'Vadodara',
#   'Shipping Province': 'GJ',
#   'Shipping Zip': "'390025"},
#  '#3192': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1605.5),
#   'Total': np.float64(1605.5),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(84.5),
#   'Shipping Name': 'Mushtaq Ahmed',
#   'Shipping Phone': '8885886542',
#   'Shipping Street': '44/19-G1, Rays Pharmacy Lane, behind Radha Krishnan hospital, Prakash Nagar',
#   'Shipping City': 'Kurnool',
#   'Shipping Province': 'AP',
#   'Shipping Zip': "'518004"},
#  '#3193': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1124.0),
#   'Total': np.float64(1124.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Akash T N',
#   'Shipping Phone': '9108580717',
#   'Shipping Street': 'Udbhava, C/O Belavadi Manjunath, Eidgah Maidan Down',
#   'Shipping City': 'Chikmagalur',
#   'Shipping Province': 'KA',
#   'Shipping Zip': "'577101"},
#  '#3194': {'Financial Status': 'paid',
#   'Subtotal': np.float64(2872.8),
#   'Total': np.float64(2872.8),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(151.2),
#   'Shipping Name': 'Vivek Srivastava',
#   'Shipping Phone': '8600155584',
#   'Shipping Street': 'K901, Aparna sarovar nallagandla',
#   'Shipping City': 'Hyderabad',
#   'Shipping Province': 'TS',
#   'Shipping Zip': "'500019"},
#  '#3195': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1220.75),
#   'Total': np.float64(1220.75),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(64.25),
#   'Shipping Name': 'Subhasatwa Sarma Roy',
#   'Shipping Phone': '8131043573',
#   'Shipping Street': 'Regional Institute of Medical Sciences Lamphel Road Lamphelpat, Gents UG hostel 1',
#   'Shipping City': 'Imphal',
#   'Shipping Province': 'MN',
#   'Shipping Zip': "'795004"},
#  '#3197': {'Financial Status': 'pending',
#   'Subtotal': np.float64(1075.0),
#   'Total': np.float64(1174.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'sachin dhamal',
#   'Shipping Phone': '9766988844',
#   'Shipping Street': 'B-1 / 4 Ramnagar housing complex gavhane vasti bhosari pune',
#   'Shipping City': 'pune',
#   'Shipping Province': 'MH',
#   'Shipping Zip': "'411039"},
#  '#3199': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1334.0),
#   'Total': np.float64(1334.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Samih Islam',
#   'Shipping Phone': '9101454156',
#   'Shipping Street': 'Gorkapon, Khadimbari, House no 242',
#   'Shipping City': 'Badarpur',
#   'Shipping Province': 'AS',
#   'Shipping Zip': "'788806"},
#  '#3204': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1234.05),
#   'Total': np.float64(1234.05),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(64.95),
#   'Shipping Name': 'jason praneeth',
#   'Shipping Phone': '7674897385',
#   'Shipping Street': 'F2, plot 156, balaji residency, road 5p, Krishna Nagar, moulaali',
#   'Shipping City': 'Hyderabad',
#   'Shipping Province': 'TS',
#   'Shipping Zip': "'500040"},
#  '#3206': {'Financial Status': 'paid',
#   'Subtotal': np.float64(799.0),
#   'Total': np.float64(799.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Omkar Kulkarni',
#   'Shipping Phone': '9665932768',
#   'Shipping Street': 'D5, D building, First Floor, Chandranil Co. Op Housing Society,, Panmala, Singhgad Road, Pune - 411030.',
#   'Shipping City': 'Pune',
#   'Shipping Province': 'MH',
#   'Shipping Zip': "'411030"},
#  '#3208': {'Financial Status': 'pending',
#   'Subtotal': np.float64(437.0),
#   'Total': np.float64(586.0),
#   'Shipping': np.float64(149.0),
#   'Discount Amount': np.float64(23.0),
#   'Shipping Name': 'Sabharwal Mrageish',
#   'Shipping Phone': '9752849397',
#   'Shipping Street': 'House number 46 CASA GREEN PRIMA TALAWALI CHANDA',
#   'Shipping City': 'Indore',
#   'Shipping Province': 'MP',
#   'Shipping Zip': "'453771"},
#  '#3211': {'Financial Status': 'paid',
#   'Subtotal': np.float64(973.75),
#   'Total': np.float64(973.75),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(51.25),
#   'Shipping Name': 'Amritha Ramakrishnan',
#   'Shipping Phone': '7845276695',
#   'Shipping Street': '145, Krishnarajapuram colony, Manamadurai, Sivagangai district, Tamilnadu',
#   'Shipping City': 'Madurai',
#   'Shipping Province': 'TN',
#   'Shipping Zip': "'630606"},
#  '#3213': {'Financial Status': 'pending',
#   'Subtotal': np.float64(1185.0),
#   'Total': np.float64(1284.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Aniket Siddhartha',
#   'Shipping Phone': '9876141029',
#   'Shipping Street': 'Holistic Health Yoga Professor Colony Brahman Majra, Behind zandu steelworks',
#   'Shipping City': 'Sirhind',
#   'Shipping Province': 'PB',
#   'Shipping Zip': "'140406"},
#  '#3214': {'Financial Status': 'paid',
#   'Subtotal': np.float64(1595.0),
#   'Total': np.float64(1595.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Kowmudi Peesapati',
#   'Shipping Phone': '6301584648',
#   'Shipping Street': 'Sabarmati Hostel Road Indian Institute Of Technology',
#   'Shipping City': 'Chennai',
#   'Shipping Province': 'TN',
#   'Shipping Zip': "'600036"},
#  '#3215': {'Financial Status': 'paid',
#   'Subtotal': np.float64(2446.25),
#   'Total': np.float64(2446.25),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(128.75),
#   'Shipping Name': 'Saket Anand',
#   'Shipping Phone': '7632814366',
#   'Shipping Street': 'House No 13-206, Plot No 264, Lakshmi Nilayam, 2nd Floor, Road No 22, Shirdi Sai Colony, Beeramguda',
#   'Shipping City': 'Hyderabad',
#   'Shipping Province': 'TS',
#   'Shipping Zip': "'502032"},
#  '#3216': {'Financial Status': 'paid',
#   'Subtotal': np.float64(774.25),
#   'Total': np.float64(774.25),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(40.75),
#   'Shipping Name': 'Syed Naimuddin',
#   'Shipping Phone': '9742817432',
#   'Shipping Street': 'Mecca Rice Mill Road, Near karnataka mutton stall',
#   'Shipping City': 'Sira',
#   'Shipping Province': 'KA',
#   'Shipping Zip': "'572137"},
#  '#3217': {'Financial Status': 'paid',
#   'Subtotal': np.float64(795.0),
#   'Total': np.float64(795.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'CD S',
#   'Shipping Phone': '7030460333',
#   'Shipping Street': 'A504, Rajaveer Palace phase 1, Rajaveer Palace, Phase 1, Pimple Saudagar, Near Pizza Hut',
#   'Shipping City': 'Pune',
#   'Shipping Province': 'MH',
#   'Shipping Zip': "'411027"},
#  '#3223': {'Financial Status': 'paid',
#   'Subtotal': np.float64(964.25),
#   'Total': np.float64(964.25),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(50.75),
#   'Shipping Name': 'Pratik C',
#   'Shipping Phone': '9099897927',
#   'Shipping Street': 'B-608, Armada Society, Parkhe Vasti Road, Hinjawadi',
#   'Shipping City': 'Hinjewadi, Pune',
#   'Shipping Province': 'MH',
#   'Shipping Zip': "'411057"},
#  '#3224': {'Financial Status': 'paid',
#   'Subtotal': np.float64(774.25),
#   'Total': np.float64(774.25),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(40.75),
#   'Shipping Name': 'Kunal devgan Devgan',
#   'Shipping Phone': '8053771716',
#   'Shipping Street': 'Bank of Baroda Ram Nagar Branch Ram Nagar, 79a, Near FCI corporation',
#   'Shipping City': 'Karnal',
#   'Shipping Province': 'HR',
#   'Shipping Zip': "'132001"},
#  '#3225': {'Financial Status': 'paid',
#   'Subtotal': np.float64(2251.5),
#   'Total': np.float64(2251.5),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(118.5),
#   'Shipping Name': 'Sourabh Kumar',
#   'Shipping Phone': '9886142825',
#   'Shipping Street': '4th Floor, L75, Block L, Malviya Nagar',
#   'Shipping City': 'New Delhi',
#   'Shipping Province': 'DL',
#   'Shipping Zip': "'110017"},
#  '#3226': {'Financial Status': 'pending',
#   'Subtotal': np.float64(1029.0),
#   'Total': np.float64(1128.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Duan Gonmei',
#   'Shipping Phone': '7005424588',
#   'Shipping Street': 'K. Sachu colony, House no. 19',
#   'Shipping City': 'Dimapur',
#   'Shipping Province': 'NL',
#   'Shipping Zip': "'797112"},
#  '#3227': {'Financial Status': 'paid',
#   'Subtotal': np.float64(299.0),
#   'Total': np.float64(398.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'Ankita Singh',
#   'Shipping Phone': '8789216040',
#   'Shipping Street': 'Nawal kishor singh, raipatti, near mission classes,Dighwara, Nawal kishor singh near mission classes raipatti',
#   'Shipping City': 'Dighwara',
#   'Shipping Province': 'BR',
#   'Shipping Zip': "'841207"},
#  '#3228': {'Financial Status': 'paid',
#   'Subtotal': np.float64(4098.0),
#   'Total': np.float64(4098.0),
#   'Shipping': np.float64(0.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'MUBEEN MA',
#   'Shipping Phone': '9656293805',
#   'Shipping Street': 'Zayans home, Jasmin villa, Melparamb, kasaragod',
#   'Shipping City': 'Kalnad',
#   'Shipping Province': 'KL',
#   'Shipping Zip': "'671317"},
#  '#3229': {'Financial Status': 'paid',
#   'Subtotal': np.float64(215.0),
#   'Total': np.float64(314.0),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(0.0),
#   'Shipping Name': 'DIlpreet Kumar',
#   'Shipping Phone': '7508788687',
#   'Shipping Street': 'MCB No Z105959, GANGA RAM WALI GALI,  NOHARIA MOHALA',
#   'Shipping City': 'Bathinda',
#   'Shipping Province': 'PB',
#   'Shipping Zip': "'151001"},
#  '#3232': {'Financial Status': 'paid',
#   'Subtotal': np.float64(204.25),
#   'Total': np.float64(303.25),
#   'Shipping': np.float64(99.0),
#   'Discount Amount': np.float64(10.75),
#   'Shipping Name': 'Sohail qureshi',
#   'Shipping Phone': '8055186018',
#   'Shipping Street': 'Malansha Chock Partur',
#   'Shipping City': 'Partur',
#   'Shipping Province': 'MH',
#   'Shipping Zip': "'431501"}}

# %%
with open(input_path, 'r', encoding='utf-8', errors='ignore', newline='') as infile, open(output_path, 'w', newline='') as outfile:
    reader = csv.DictReader(infile)
    writer = csv.DictWriter(outfile, fieldnames=output_columns)
    writer.writeheader()

    for row in reader:
        transformed_dict = {}
        order_number = row["Name"]
        for column in output_columns:
            if column == "*Sale Order Number":
                transformed_dict[column] = row["Name"].replace("#","")
            elif column == "*Pickup Location Name":
                transformed_dict[column] = "Sillage"
            elif column == "*Transport Mode":
                transformed_dict[column] = "Express"
            elif column == "*Payment Mode":
                if group_order_dict[order_number].get("Financial Status", "") == "paid":
                    transformed_dict[column] = "Prepaid"
                else:
                    transformed_dict[column] = "COD"
            elif column == "COD Amount":
                if group_order_dict[order_number].get("Financial Status", "") != "paid":
                    transformed_dict[column] = group_order_dict[order_number]['Total']
                else:
                    transformed_dict[column] = ""
            elif column == "*Customer Name":
                transformed_dict[column] = group_order_dict[order_number]["Shipping Name"]
            elif column == "*Customer Phone":
                transformed_dict[column] = group_order_dict[order_number]["Shipping Phone"]
            elif column == "*Shipping Address Line1":
                transformed_dict[column] = group_order_dict[order_number]["Shipping Street"]
            elif column == "Shipping Address Line2":
                transformed_dict[column] = ""
            elif column == "*Shipping City":
                transformed_dict[column] = group_order_dict[order_number]["Shipping City"]
            elif column == "*Shipping State":
                transformed_dict[column] = group_order_dict[order_number]["Shipping Province"]
            elif column == "*Shipping Pincode":
                transformed_dict[column] = group_order_dict[order_number]["Shipping Zip"].replace("'","")
            elif column == "*Item Sku Code":
                transformed_dict[column] = generate_random_alphanumeric(7)
            elif column == "*Item Sku Name":
                transformed_dict[column] = " ".join(row["Lineitem name"].split()[:2])
            elif column == "*Quantity Ordered":
                transformed_dict[column] = row["Lineitem quantity"]
            elif column == "Packaging Type":
                transformed_dict[column] = "Plastic cover/Flyer"
            elif column == "*Unit Item Price":
                transformed_dict[column] = row["Lineitem price"]
            elif column == "Length (cm)":
                transformed_dict[column] = "18"
            elif column == "Breadth (cm)":
                transformed_dict[column] = "8"
            elif column == "Height (cm)":
                transformed_dict[column] = "25"
            elif column == "Weight (gm)":
                transformed_dict[column] = "450"
            elif column == "Fragile Shipment":
                transformed_dict[column] = "Yes"
            elif column == "Customer Email":
                transformed_dict[column] = row['Email']
            elif column == "Billing Address same as Shipping Address":
                transformed_dict[column] = "Yes"
            else:
                transformed_dict[column] = ""
        
        writer.writerow(transformed_dict)
